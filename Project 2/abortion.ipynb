# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the dataset
file_path = "GuttmacherInstituteAbortionDataByState.csv"

df = pd.read_csv(file_path)

df.head()
# Out:
#    U.S. State  % change in abortion rate, 2017-2020  \
# 0     Alabama                                    -6
# 1      Alaska                                     0
# 2     Arizona                                     1
# 3    Arkansas                                     2
# 4  California                                    17
#
#    % change in the no. of abortion clinics, 2017-2020  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                -33
# 4                                                  7
#
#    % change in the no. of abortion providers, 2014-2017  \
# 0                                                -22
# 1                                                -25
# 2                                                 -8
# 3                                                  0
# ...
